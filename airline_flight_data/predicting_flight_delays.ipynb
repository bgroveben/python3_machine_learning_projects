# %% [markdown]
# # [Predicting Flight Delays Tutorial](https://www.kaggle.com/fabiendaniel/predicting-flight-delays-tutorial/notebook)

# %%
import datetime, warnings, scipy 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import ConnectionPatch
from collections import OrderedDict
from matplotlib.gridspec import GridSpec
# https://github.com/matplotlib/basemap
# from mpl_toolkits.basemap import Basemap
from sklearn import metrics, linear_model
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from scipy.optimize import curve_fit
plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.options.display.max_columns = 50
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# This notebook will develop a model aimed at predicting flight delays at take-off.
# The focus is not on the results but instead on the process behind developing a machine learning classifier that can do the job.
# We will discuss separating your data into training and test sets, how to build linear and polynomial models for univariate or multivariate regressions, and how to regularize parameters.

# %% [markdown]
# Let's have a quick look at our data:

# %%
df = pd.read_csv('flight_delays_data/flights.csv', low_memory=False)
df.shape
# Out:
# (5819079, 31)

# %%
df.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %% [markdown]
# A description of the variable names [can be found here](https://www.transtats.bts.gov/DL_SelectFields.asp?Table_ID=236&DB_Short_Name=On-Time), and we can see that we are dealing with ~5.8 million flights from 2015.
# The categories that we will deal with in this notebook are:
# * **YEAR, MONTH, DAY, DAY_OF_WEEK**: dates of the flight.
# * **AIRLINE**: An identification number assigned by US DOT to identify a unique airline.
# * **ORIGIN_AIRPORT and DESTINATION_AIRPORT**: code attributed by IATA to identify the airports.
# * **SCHEDULED_DEPARTURE and SCHEDULED_ARRIVAL**: scheduled times of take-off and landing.
# * **DEPARTURE_TIME and ARRIVAL_TIME**: real times at which take-off and landing took place.
# * **DEPARTURE_DELAY and ARRIVAL_DELAY**: difference (in minutes) between planned and real times.
# * **DISTANCE**: distance (in miles)

# %% [markdown]
# Let's find out about the column types and number of null values:

# %%
tab_info = pd.DataFrame(df.dtypes).T.rename(index={0:'column type'})
tab_info
# Out:
#               YEAR  MONTH    DAY DAY_OF_WEEK AIRLINE FLIGHT_NUMBER  \
# column type  int64  int64  int64       int64  object         int64
#
#             TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# column type      object         object              object
#
#             SCHEDULED_DEPARTURE DEPARTURE_TIME DEPARTURE_DELAY TAXI_OUT  \
# column type               int64        float64         float64  float64
#
#             WHEELS_OFF SCHEDULED_TIME ELAPSED_TIME AIR_TIME DISTANCE  \
# column type    float64        float64      float64  float64    int64
#
#             WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME ARRIVAL_DELAY  \
# column type   float64  float64             int64      float64       float64
#
#             DIVERTED CANCELLED CANCELLATION_REASON AIR_SYSTEM_DELAY  \
# column type    int64     int64              object          float64
#
#             SECURITY_DELAY AIRLINE_DELAY LATE_AIRCRAFT_DELAY WEATHER_DELAY
# ...

# %%
tab_info = tab_info.append(pd.DataFrame(df.isnull().sum()).T.rename(index={0:'null values'}))
tab_info
# Out:
#               YEAR  MONTH    DAY DAY_OF_WEEK AIRLINE FLIGHT_NUMBER  \
# column type  int64  int64  int64       int64  object         int64
# null values      0      0      0           0       0             0
#
#             TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# column type      object         object              object
# null values       14721              0                   0
#
#             SCHEDULED_DEPARTURE DEPARTURE_TIME DEPARTURE_DELAY TAXI_OUT  \
# column type               int64        float64         float64  float64
# null values                   0          86153           86153    89047
#
#             WHEELS_OFF SCHEDULED_TIME ELAPSED_TIME AIR_TIME DISTANCE  \
# column type    float64        float64      float64  float64    int64
# null values      89047              6       105071   105071        0
#
#             WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME ARRIVAL_DELAY  \
# ...

# %%
tab_info = tab_info.append(pd.DataFrame(df.isnull().sum() / df.shape[0] * 100).T.rename(index={0:'% null values'}))
tab_info
# Out:
#                 YEAR  MONTH    DAY DAY_OF_WEEK AIRLINE FLIGHT_NUMBER  \
# column type    int64  int64  int64       int64  object         int64
# null values        0      0      0           0       0             0
# % null values      0      0      0           0       0             0
#
#               TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# column type        object         object              object
# null values         14721              0                   0
# % null values    0.252978              0                   0
#
#               SCHEDULED_DEPARTURE DEPARTURE_TIME DEPARTURE_DELAY TAXI_OUT  \
# column type                 int64        float64         float64  float64
# null values                     0          86153           86153    89047
# % null values                   0        1.48053         1.48053  1.53026
#
#               WHEELS_OFF SCHEDULED_TIME ELAPSED_TIME AIR_TIME DISTANCE  \
# ...
